# %% [markdown]
# # Autoseed v2.2 notebook
#
# This notebook is a front-end for the Autoseed v2.2 pipeline.
#
# - **Edit only the parameter cell below**.
# - The compiled C tools will be installed by the `autoseed` pip package.
# - You can paste or adapt your existing `autoseed_v2.2.py` logic into the last cell.

# %%
# === PARAMETERS (EDIT THIS CELL ONLY) ===

INPUT_BG = "80bpshuffled.seq"          # background sequences
INPUT_SIGNAL = "STARRseq_promoter_80bp.seq"  # signal sequences

# seed search parameters
min_seed = 5
max_seed = 8
top_seeds = 100

# seed extension parameters
extend_k = 4
extend_top = 100

# motif / SVG generation parameters
min_prob = 0.35
distill = 1
svg_prob = 0.20

OUTPUT_SVG = "autoseed_output.svg"  # suggested output name

# %%
from autoseed.runner import localmax, seedext, sim, genint
import pathlib, subprocess

print("Autoseed notebook environment ready.")
print("Background:", INPUT_BG)
print("Signal:", INPUT_SIGNAL)

# %% [markdown]
# ## Pipeline
#
# Below is a placeholder cell. Here you can paste or adapt the logic from your
# original `autoseed_v2.2.py` script, using the parameters defined above and the
# four helper functions:
#
# - `localmax(args)`
# - `seedext(args)`
# - `sim(args)`
# - `genint(args)`
#
# Each helper runs the corresponding compiled C executable and returns a
# `subprocess.CompletedProcess` object.

# %%
# TODO: implement the full Autoseed v2.2 pipeline here by
# adapting the original autoseed_v2.2.py script.
# The parameters from the first cell are available as Python variables.

print("Example: this is where the autoseed_v2.2 logic will go.")

# Example (placeholder) calls – update to match your actual pipeline:
# res_localmax = localmax([INPUT_BG, INPUT_SIGNAL, min_seed, max_seed, top_seeds])
# res_seedext  = seedext([extend_k, extend_top])
# res_sim      = sim([])
# res_gen      = genint([svg_prob])

print("Pipeline placeholder executed.")
